# %%
# %pylab inline
from astropy.table import Table
import sys
sys.path.append('../bok')
import bokrmphot
import bokrmgnostic
import os
print os.environ.setdefault('BOKRMDIR','../bok')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/ian/dev/idmrm/bok

# %%
sdssRefPhot = Table.read('../bokrmphot_sdssstars.fits')
sdssRefPhot = bokrmphot.load_full_ref_cat(sdssRefPhot)

# %%
bokrmphot.calc_color_terms(sdssRefPhot,'g',doplots=True,savefit=True)
# Out:
# /Users/ian/anaconda/lib/python2.7/site-packages/astropy/table/column.py:1095: MaskedArrayFutureWarning: setting an item on a masked array which has a shared mask will not copy the mask and also change the original mask array in the future.
# Check the NumPy 1.11 release notes for more information.
#   ma.MaskedArray.__setitem__(self, index, value)
# /Users/ian/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
bokrmphot.calc_color_terms(sdssRefPhot,'i',doplots=True,savefit=True)
# Out:
# /Users/ian/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/ian/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
zpTab = Table.read('../bok/bokrm_zeropoints.fits')
obsDb = Table.read('../bok/config/sdssrm-bok.fits.gz')

# %%
_ = bokrmgnostic.add_photometric_flag(zpTab,obsDb,doplot=True)
