# %%
# %pylab inline
from astropy.table import Table
import sys
sys.path.append('..')
import bokrmphot
# Out:
# Populating the interactive namespace from numpy and matplotlib
# '/home/ian/dev/bokrm'

# %%
band='g'
sdssRefPhot = Table.read('../lightcurves_bokrm_sdss_%s.fits'%band)

# %%
sdssRefPhot = bokrmphot.load_full_ref_cat(sdssRefPhot,band)

# %%
bokrmphot.calc_color_terms(sdssRefPhot,doplots=True,savefit=True)
# Out:
# /home/ian/soft/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
